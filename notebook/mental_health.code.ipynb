# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def opening_csv(filepath):
    df = pd.read_csv(filepath)
    return df

lstyle_df = opening_csv('../data/Mental_Health_Lifestyle_Dataset.csv')
lstyle_copy = lstyle_df.copy()
print(lstyle_copy.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      3000 non-null   object
#  1   Age                          3000 non-null   int64
#  2   Gender                       3000 non-null   object
#  3   Exercise Level               3000 non-null   object
#  4   Diet Type                    3000 non-null   object
#  5   Sleep Hours                  3000 non-null   float64
#  6   Stress Level                 3000 non-null   object
#  7   Mental Health Condition      2405 non-null   object
#  8   Work Hours per Week          3000 non-null   int64
#  9   Screen Time per Day (Hours)  3000 non-null   float64
#  10  Social Interaction Score     3000 non-null   float64
#  11  Happiness Score              3000 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# ...

# %%
def initial_look(df):
    return df.sample(10)

initial_look(lstyle_copy)
# Initital Inspect - Mental Health Condition = NaN -> have to fill it in
# Review Mental Health forms
# Out:
#      Country  Age  Gender Exercise Level   Diet Type  Sleep Hours  \
# 1999   India   58    Male       Moderate  Vegetarian          5.0
# 439    India   61  Female           High    Balanced          5.3
# 2859   India   34    Male           High        Keto          8.8
# 1725   Japan   32    Male            Low        Keto          5.9
# 1990   India   20   Other           High   Junk Food          8.6
# 1040   India   23   Other            Low   Junk Food          5.8
# 2138  Canada   27   Other       Moderate  Vegetarian          6.1
# 740   Brazil   36   Other           High        Keto          6.2
# 2553     USA   34  Female           High    Balanced          5.3
# 2178     USA   39   Other       Moderate    Balanced          7.4
#
#      Stress Level Mental Health Condition  Work Hours per Week  \
# 1999          Low              Depression                   54
# 439          High                     NaN                   26
# ...

# %% [markdown]
# Describe the available fields.
#
# How many categorical fields? What do they represent?
#
# 12 Columns
# Qualitative(6) - Country, Gender, Exercise Level, Diet Type, Stress Level, Mental Health Condition
#
# - Nominal (1)- Mental Health Condition
# - Ordinal (5) - Country, Gender, Diet Type, Stress Level, Execrise Level

# %%
lstyle_copy['Mental Health Condition'].value_counts()
# Need to add another category - N/A or (depends on the direction where I can go with)
# Bell Curve - outlier
# Out:
# Mental Health Condition
# Anxiety       628
# PTSD          624
# Depression    580
# Bipolar       573
# Name: count, dtype: int64

# %% [markdown]
# Quantitative(6) - Age, Sleep Hours, Stress Level, Mental Health Condition, Work Hours Per Week, Screen Time per Days(Hours), Social Interaction Score, Happiness Score
#
# - Continous (4-5)- Sleep hours, Screen Time, Social Interaction, Happiness
# - Discrete (1-2)- Age, Workhours (can be argued for both)

# %% [markdown]
# If the data in this dataset has already been summed, averaged, or aggregated in some other way, much of the types of data work you would like to demonstrate has already been done.
# Is there missing data or data that seems to be wrong somehow (e.g. age = -99)? Has the data already been summarized, or are the observations raw and unprocessed?
#
# Review the description -
# No missing data - but we can fill NaN with another category
#
# # Data authenticity - exploratory or practice purposes. No claimed Sources

# %%
lstyle_copy.groupby("Exercise Level")['Stress Level'].value_counts()
# Out:
# Exercise Level  Stress Level
# High            High            342
#                 Moderate        324
#                 Low             303
# Low             Low             357
#                 Moderate        350
#                 High            326
# Moderate        Low             348
#                 High            334
#                 Moderate        316
# Name: count, dtype: int64
